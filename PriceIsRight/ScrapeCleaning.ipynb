# %%
import os
import sys
import datetime
import numpy as np
import pickle
import pandas as pd
import datetime
import re
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
main_file_path = r"Data\pir_Check.csv"
main_df = pd.read_csv(main_file_path, parse_dates=['airDate']).drop_duplicates()
main_df.head(3)
# Out:
#                                  url episodeID  errorCode  \
# 0   https://tpirepguide.com/?p=18052     9782K          0
# 10  https://tpirepguide.com/?p=18045     9781K          0
# 11  https://tpirepguide.com/?p=18018     9775K          0
#
#                                       footer  urlParam EpsCategory    airDate
# 0   March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 10  March 28th, 2022 |  Category: Carey Eps      18045   Carey Eps 2022-03-28
# 11  March 25th, 2022 |  Category: Carey Eps      18018   Carey Eps 2022-03-25

# %%
main_df.shape
# Out:
# (6231, 7)

# %% [markdown]
# ### Showcase Spins

# %%
sc_file_path = r"Data\pir_Content.csv"
sc_df = pd.read_csv(sc_file_path).drop_duplicates()
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1         Comments  \
# 0       1      1,340    Maurice    85     0    85   NaN               C:
# 1       2      8,531        Kim     1     0     1  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra    20    50    70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4
# 0      SS1    9782K  NaN  NaN  NaN
# 1      SS1    9782K  NaN  NaN  NaN
# 2      SS1    9782K  NaN  NaN  NaN

# %%
sc_df.shape
# Out:
# (26959, 13)

# %%
raw_df = sc_df.copy()

# %% [markdown]
# ### Showcase HouseKeeping
# - Three contestants for each showcase portion
# - Add Contestant Order
# - Check for "=" in Total Column

# %%
def keep_only_with_three(df):
    """Keep only those that have 3 contestants"""
    contestant_counts = df.groupby(['urlParam', 'Showcase']).SC_ind.count().reset_index()
    display(contestant_counts.SC_ind.value_counts(normalize=True))
    keeps = contestant_counts.loc[contestant_counts.SC_ind == 3].copy()
    df = df.merge(keeps, how='inner', on=['urlParam', 'Showcase'], suffixes=("", "_e"))
    del df['SC_ind_e']
    return df

# %%
sc_df = keep_only_with_three(sc_df)
# Out:
# 3    0.937824
# 2    0.026518
# 6    0.025276
# 1    0.006319
# 4    0.002708
# 5    0.001354
# Name: SC_ind, dtype: float64

# %%
print(sc_df.shape)
sc_df.head(3)
# Out:
# (24933, 13)
#    SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1         Comments  \
# 0       1      1,340    Maurice    85     0    85   NaN               C:
# 1       2      8,531        Kim     1     0     1  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra    20    50    70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4
# 0      SS1    9782K  NaN  NaN  NaN
# 1      SS1    9782K  NaN  NaN  NaN
# 2      SS1    9782K  NaN  NaN  NaN

# %% [markdown]
# #### Create Contestant Order Column

# %%
sc_df['ContestantOrder'] = sc_df.groupby(['urlParam', 'Showcase'])['SC_ind'].rank()
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1         Comments  \
# 0       1      1,340    Maurice    85     0    85   NaN               C:
# 1       2      8,531        Kim     1     0     1  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra    20    50    70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder
# 0      SS1    9782K  NaN  NaN  NaN              1.0
# 1      SS1    9782K  NaN  NaN  NaN              2.0
# 2      SS1    9782K  NaN  NaN  NaN              3.0

# %%
sc_df.ContestantOrder.value_counts()
# Out:
# 2.0    8311
# 3.0    8311
# 1.0    8311
# Name: ContestantOrder, dtype: int64

# %% [markdown]
# #### Clean Up Comments

# %%
sc_df['CommNums'] = sc_df.Comments.apply(lambda x: re.findall(r'[\d]*\.[\d]+', x))

# %% [markdown]
# EV3 Populated

# %%
sc_df.loc[(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev3.isna())]
# Out:
#        SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1  \
# 17915       4      5,340    Jeffrey  0.55  0.05     =  35.0
#
#                                          Comments Showcase urlParam   ev2  \
# 17915  C: 0.60 Jeffrey FINALLY goes to Showcase!!      SS1    0042K  60.0
#
#         ev3  ev4  ContestantOrder CommNums
# 17915  45.0  NaN              3.0   [0.60]

# %%
# In above the 0.60 is the total
sc_df['Total'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev3.isna())],
                          [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)], sc_df.Total)

# %%
sc_df['Fixed'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev3.isna()),
                           (sc_df.CommNums.apply(lambda x: len(x)) < 1) & (sc_df.Total != "=")], [True, True], False)

# %% [markdown]
# EV2 Populated

# %%
sc_df.loc[(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev2.isna()) & ~sc_df.Fixed]
# Out:
#        SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1  \
# 2345        4     12,866    Marilyn    80     0    80  90.0
# 15733       3     1,574+     Donald    25    65     =  90.0
# 22075       3      1,049        Jan    55    25    80  55.0
# 22823       4      5,141    Stephen    50     0    50  45.0
#
#                    Comments Showcase urlParam   ev2  ev3  ev4  \
# 2345   C: 1.00 Bonus Spin ►      SS2    8911K  25.0  NaN  NaN
# 15733         C: 1.00 BONUS      SS2    1392K  90.0  NaN  NaN
# 22075  C: 1.00 Bonus Spin >      SS1    5265D  20.0  NaN  NaN
# 22823  C: 1.00 Bonus Spin >      SS1    4993D  60.0  NaN  NaN
#
#        ContestantOrder CommNums  Fixed
# 2345               3.0   [1.00]  False
# 15733              2.0   [1.00]  False
# 22075              2.0   [1.00]  False
# 22823              3.0   [1.00]  False

# %%
# Fix these, if = ev1 is total and CommNums needs to go to ev1; Else comm needs to go to ev2 and ev2 to 3
sc_df['WorkingOn'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev2.isna()) & (~sc_df.Fixed)],
                              [True], False)
sc_df['ev3'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')], [sc_df.ev2], sc_df.ev3)
sc_df['ev2'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)], sc_df.ev2)
# Update working on to those with "=" in total
sc_df['WorkingOn'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != "="), sc_df.WorkingOn], [False, True], False)
sc_df['Total'] = np.select([(sc_df.WorkingOn)], [sc_df.ev1], sc_df.Total)
sc_df['ev1'] = np.select([(sc_df.WorkingOn)], [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)], sc_df.ev1)

# %%
sc_df['Fixed'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev2.isna()) & ~sc_df.Fixed], [True],
                           sc_df.Fixed)

# %% [markdown]
# EV1 Populated

# %%
sc_df[(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev1.isna()) & ~sc_df.Fixed & (sc_df.Total == "=")].head(3)
# Out:
#        SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1  \
# 16495       2      1,500   Patricia    25    75     =  10.0
# 16608       1        950       Ryan    40    60     =  65.0
# 16609       2      1,499      Marni    55    45     =  55.0
#
#                       Comments Showcase urlParam  ev2  ev3  ev4  \
# 16495           C: 1.00 BONUS:      SS1    1072K  NaN  NaN  NaN
# 16608  C: 1.00 to the showcase    SSBSO    1015K  NaN  NaN  NaN
# 16609                  C: 1.00    SSBSO    1015K  NaN  NaN  NaN
#
#        ContestantOrder CommNums  Fixed  WorkingOn
# 16495              2.0   [1.00]  False      False
# 16608              1.0   [1.00]  False      False
# 16609              2.0   [1.00]  False      False

# %%
sc_df[(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev1.isna()) & ~sc_df.Fixed & (sc_df.Total != "=")].head(3)
# Out:
#       SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1  \
# 349        3     13,086    William    65    20    85  40.0
# 591        2        530      Kelly    65     0    65  15.0
# 1065       2      8,394      Kevin    25    65    90  90.0
#
#                      Comments Showcase urlParam  ev2  ev3  ev4  \
# 349      C: 1.00 Bonus Spin >      SS1    9661K  NaN  NaN  NaN
# 591   C: 1.00 Bonus Spin ► DQ      SS1    9563K  NaN  NaN  NaN
# 1065     C: 1.00 Bpnus Spin ►      SS1    9405K  NaN  NaN  NaN
#
#       ContestantOrder CommNums  Fixed  WorkingOn
# 349               2.0   [1.00]  False      False
# 591               1.0   [1.00]  False      False
# 1065              1.0   [1.00]  False      False

# %%
sc_df['WorkingOn'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev1.isna()) & (~sc_df.Fixed)],
                              [True], False)
sc_df['ev2'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')], [sc_df.ev1], sc_df.ev2)
sc_df['ev1'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)], sc_df.ev1)
# Update working on to those with "=" in total
sc_df['WorkingOn'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != "="), sc_df.WorkingOn], [False, True], False)
sc_df['Total'] = np.select([(sc_df.WorkingOn)],  [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)],
                           sc_df.Total)

# %%
sc_df['Fixed'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (~sc_df.ev1.isna()) & ~sc_df.Fixed], [True],
                           sc_df.Fixed)

# %% [markdown]
# No Extra Values Populated

# %%
sc_df.loc[(sc_df.CommNums.apply(lambda x: len(x)) > 1) & (sc_df.ev1.isna()) & ~sc_df.Fixed]
# Out:
#        SC_ind PrizeValue Contestant Spin1 Spin2 Total  ev1  \
# 1260        2      1,499     Robert    85     0    85  NaN
# 2273        4      1,799    Anthony    60    10    70  NaN
# 15707       4     14,360     Ralph:   0.5  0.25     =  NaN
# 16477       2      1,130      Sammy     5    95     =  NaN
# 17918       3     20,001      Renee   0.7   0.3     =  NaN
# 19331       4      3,811       Joan    90     0    90  NaN
# 23793       1        730   Aniteria  0.35  0.65     =  NaN
#
#                                      Comments Showcase urlParam  ev2  ev3  \
# 1260   C: 1.00 Bonus Spin ► 1.00 25,000 Bonus      SS1    9333K  NaN  NaN
# 2273                C: 1.00 1.00 25,000 Bonus      SS1    8942K  NaN  NaN
# 15707               C: 0.75 1.00 Bonus > 0.90     SS1:    1401K  NaN  NaN
# 16477             C: 1.00 BONUS 1.00 *10,000*      SS1    1081K  NaN  NaN
# 17918               C: 1.00 Bonus Spin = 0.25      SS2    0042K  NaN  NaN
# 19331  C: 1.00 Bonus Spin > 1.00 10,000 Bonus      SS1    8793D  NaN  NaN
# 23793               C: 1.00 Bonus Spin - 0.70     SS2:    4641D  NaN  NaN
#
#        ev4  ContestantOrder            CommNums  Fixed  WorkingOn
# 1260   NaN              1.0        [1.00, 1.00]  False      False
# 2273   NaN              3.0        [1.00, 1.00]  False      False
# 15707  NaN              3.0  [0.75, 1.00, 0.90]  False      False
# 16477  NaN              2.0        [1.00, 1.00]  False      False
# 17918  NaN              3.0        [1.00, 0.25]  False      False
# 19331  NaN              3.0        [1.00, 1.00]  False      False
# 23793  NaN              1.0        [1.00, 0.70]  False      False

# %%
sc_df['WorkingOn'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & (sc_df.ev1.isna()) & (~sc_df.Fixed)],
                              [True], False)
sc_df['ev1'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)], sc_df.ev1)
sc_df['ev2'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[1] if len(x) > 1 else None)], sc_df.ev2)
# Update working on to those with "=" in total
sc_df['WorkingOn'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != "="), sc_df.WorkingOn], [False, True], False)
sc_df['Total'] = np.select([(sc_df.WorkingOn)],  [sc_df.CommNums.apply(lambda x: x[0] if len(x) > 0 else None)],
                           sc_df.Total)
sc_df['ev1'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[1] if len(x) > 1 else None)], sc_df.ev1)
sc_df['ev2'] = np.select([(sc_df.WorkingOn) & (sc_df.Total != '=')],
                         [sc_df.CommNums.apply(lambda x: x[2] if len(x) > 2 else None)], sc_df.ev2)

# %%
sc_df['Fixed'] = np.select([(sc_df.CommNums.apply(lambda x: len(x)) > 0) & ~sc_df.Fixed], [True],
                           sc_df.Fixed)

# %% [markdown]
# Those with no values in the comments but an Equals in the Total

# %%
sc_df.loc[~sc_df.Fixed].shape, sc_df.loc[~sc_df.Fixed & (sc_df.Total == "=")].shape
# Out:
# ((1604, 17), (1604, 17))

# %%
sc_df.loc[~sc_df.Fixed & ~sc_df.ev4.isna()]
# Out:
#        SC_ind PrizeValue   Contestant Spin1 Spin2 Total   ev1  \
# 15453       2      1,770  Christopher    45    45     =  90.0
# 16540       3      1,645       Daniel     5    80     =  85.0
# 16541       4      4,025        Jaime    50    35     =  85.0
#
#                           Comments Showcase urlParam   ev2    ev3   ev4  \
# 15453                C: bonus spin      SS1    1511K  55.0  100.0  95.0
# 16540  C: Through to the Showcases      SS2    1051K  10.0   50.0  95.0
# 16541                           C:      SS2    1051K  10.0   50.0  10.0
#
#        ContestantOrder CommNums  Fixed  WorkingOn
# 15453              1.0       []  False      False
# 16540              2.0       []  False      False
# 16541              3.0       []  False      False

# %%
# Move everything forward
sc_df['Total'] = np.select([~sc_df.Fixed], [sc_df.ev1], sc_df.Total)
sc_df['ev1'] = np.select([~sc_df.Fixed], [sc_df.ev2], sc_df.ev1)
sc_df['ev2'] = np.select([~sc_df.Fixed], [sc_df.ev3], sc_df.ev2)
sc_df['ev3'] = np.select([~sc_df.Fixed], [sc_df.ev4], sc_df.ev3)
sc_df['ev4'] = np.select([~sc_df.Fixed], [None], sc_df.ev4)

# %%
# All done
del sc_df['Fixed']
del sc_df['WorkingOn']

# %%
new_base = sc_df.copy()

# %% [markdown]
# ### Confirm Numbers in Spin1, Spin2, and Total

# %%
def make_numeric_column(df, col):
    df[col + '_test'] = df[col].astype(str).str.replace(r'[\.,$\s\+\*-]', '', regex=True)
    # replace empty string with 0
    df[col + '_test'] = np.select([df[col + '_test'] == ''], [0], df[col + '_test'])
    num_numeric = sum(df[col + '_test'].apply(lambda x: str(x).isnumeric()))
    if num_numeric == len(df):
        df[col] = df[col + '_test']
        del df[col + '_test']
    return df

# %%
sc_df = make_numeric_column(sc_df, 'Spin1')
sc_df = make_numeric_column(sc_df, 'Spin2')

# %%
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1         Comments  \
# 0       1      1,340    Maurice    85     0    85   NaN               C:
# 1       2      8,531        Kim     1     0     1  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra    20    50    70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Spin2_test
# 0      SS1    9782K  NaN  NaN  NaN              1.0       []          0
# 1      SS1    9782K  NaN  NaN  NaN              2.0       []          0
# 2      SS1    9782K  NaN  NaN  NaN              3.0       []         50

# %%
sc_df.loc[~sc_df.Spin2_test.apply(lambda x: str(x).isnumeric())]
# Out:
#        SC_ind PrizeValue Contestant Spin1      Spin2 Total   ev1 Comments  \
# 17309       4      1,539   Caralisa    15      (Boo)    45  60.0     C: =
# 17694       1        560   Kristina     5  (Wheelie)     5  10.0     C: =
#
#       Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Spin2_test
# 17309      SS2    0495K  NaN  NaN  NaN              3.0       []      (Boo)
# 17694      SS1    0243K  NaN  NaN  NaN              1.0       []  (Wheelie)

# %%
# Would just drop if writing a script, but will fix here as easy enough
sc_df['fixMe'] = ~sc_df['Spin2_test'].apply(lambda x: str(x).isnumeric())
sc_df['Spin2'] = np.select([sc_df.fixMe], [sc_df.Total], sc_df['Spin2_test'])
sc_df['Total'] = np.select([sc_df.fixMe], [sc_df.ev1], sc_df['Total'])
sc_df['Comments'] = np.select([sc_df.fixMe], [sc_df['Comments'] + sc_df.Spin2_test.astype(str)], sc_df['Comments'])
sc_df.loc[sc_df.fixMe]
# Out:
#        SC_ind PrizeValue Contestant Spin1 Spin2 Total   ev1       Comments  \
# 17309       4      1,539   Caralisa    15    45  60.0  60.0      C: =(Boo)
# 17694       1        560   Kristina     5     5  10.0  10.0  C: =(Wheelie)
#
#       Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Spin2_test  \
# 17309      SS2    0495K  NaN  NaN  NaN              3.0       []      (Boo)
# 17694      SS1    0243K  NaN  NaN  NaN              1.0       []  (Wheelie)
#
#        fixMe
# 17309   True
# 17694   True

# %%
del sc_df['Spin2_test']
del sc_df['fixMe']

# %%
sc_df['Spin1'] = sc_df['Spin1'].astype(np.int64)
sc_df['Spin2'] = sc_df['Spin2'].astype(np.int64)
sc_df = make_numeric_column(sc_df, 'Total')
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2 Total   ev1         Comments  \
# 0       1      1,340    Maurice     85      0    85   NaN               C:
# 1       2      8,531        Kim      1      0     1  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra     20     50    70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Total_test
# 0      SS1    9782K  NaN  NaN  NaN              1.0       []         85
# 1      SS1    9782K  NaN  NaN  NaN              2.0       []          1
# 2      SS1    9782K  NaN  NaN  NaN              3.0       []         70

# %%
sc_df['fixMe'] = ~sc_df['Total_test'].apply(lambda x: str(x).isnumeric())
sc_df.loc[sc_df.fixMe].Total_test.value_counts()
# Out:
# OVER       322
# OV         214
# nan         12
# Through      4
# Bonus        3
# bonus        1
# Name: Total_test, dtype: int64

# %% [markdown]
# #### Clean up values if not between 5 and 100 or multiple of 5

# %%
sc_df.loc[(sc_df.Spin1 < 5) | ((sc_df.Spin2 < 5) & (sc_df.Spin2 > 0))]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 1           2      8,531        Kim      1      0      1  50.0
# 9           1        750       Ruby      1      0      1  80.0
# 11          3      9,168     Rachel     70      1     71   NaN
# 20          3      3,138     Lorrie     40      1     41   NaN
# 29          3      3,089    Lucille     10      1     11   NaN
# ...       ...        ...        ...    ...    ...    ...   ...
# 21752       3      7,786     Cheryl      1      0      1  1.00
# 21761       3      3,220      Joyce      1      0      1  30.0
# 21765       1        365       Jean      1      0      1  20.0
# 21780       1        924      Lynne     45      1     46   NaN
# 21785       3      3,964    Shelley      1      0      1  95.0
#
#                                 Comments Showcase urlParam   ev2  ev3  ev4  \
# 1                        C: Bonus Spin ►      SS1    9782K   NaN  NaN  NaN
# 9                        C: Bonus Spin >      SS2    9781K   NaN  NaN  NaN
# 11                                    C:      SS2    9781K   NaN  NaN  NaN
# 20                                    C:      SS1    9774K   NaN  NaN  NaN
# 29                                    C:      SS2    9773K   NaN  NaN  NaN
# ...                                  ...      ...      ...   ...  ...  ...
# 21752  C: Bonus Spin > 1.00 10,000 Bonus      SS2    5384D  None  NaN  NaN
# 21761                    C: Bonus Spin >      SS1    5382D   NaN  NaN  NaN
# 21765                    C: Bonus Spin >      SS1    5381D   NaN  NaN  NaN
# 21780                                 C:      SS2    5374D   NaN  NaN  NaN
# 21785                    C: Bonus Spin >      SS1    5373D   NaN  NaN  NaN
#
#        ContestantOrder CommNums Total_test
# 1                  2.0       []          1
# 9                  1.0       []          1
# 11                 3.0       []         71
# 20                 3.0       []         41
# 29                 3.0       []         11
# ...                ...      ...        ...
# 21752              3.0   [1.00]          1
# 21761              3.0       []          1
# 21765              1.0       []          1
# 21780              1.0       []         46
# 21785              3.0       []          1
#
# [1361 rows x 16 columns]

# %%
sc_df.loc[(sc_df.Spin1 > 100) | (sc_df.Spin2 > 100)]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test]
# Index: []

# %%
sc_df['Spin1'] = np.select([sc_df.Spin1 < 5], [sc_df.Spin1 * 100], sc_df.Spin1)
sc_df['Spin2'] = np.select([sc_df.Spin2 < 5], [sc_df.Spin2 * 100], sc_df.Spin2)
sc_df['Spin1'] = sc_df['Spin1'].astype(np.int64)
sc_df['Spin2'] = sc_df['Spin2'].astype(np.int64)
sc_df.loc[(sc_df.Spin1 > 100) | (sc_df.Spin2 > 100)]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 15709       2      5,668    Tamera:    300     45     48  None
# 16500       1      1,070   Yolanda:     15    400     19   NaN
# 17494       2      5,319     Angela    200      0      2  15.0
# 17916       1      1,067      James    300      6      9  None
# 17918       3     20,001      Renee      7    300     10  0.25
#
#                                      Comments Showcase urlParam   ev2   ev3  \
# 15709  C: 0.75 advances to the Showcase Round     SS2:    1401K  None   NaN
# 16500             C: Through to the Showcases     SS1:    1071K   NaN   NaN
# 17494                                  C: + =      SS1    0355K  20.0  45.0
# 17916                                 C: 0.90      SS2    0042K  None   NaN
# 17918               C: 1.00 Bonus Spin = 0.25      SS2    0042K  None   NaN
#
#        ev4  ContestantOrder      CommNums Total_test
# 15709  NaN              2.0        [0.75]        075
# 16500  NaN              1.0            []        055
# 17494  NaN              2.0            []          2
# 17916  NaN              1.0        [0.90]        090
# 17918  NaN              3.0  [1.00, 0.25]        100

# %%
sc_df.loc[(sc_df.Spin1 % 5 != 0) | (sc_df.Spin2 % 5 != 0)]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 10990       2      8,892        Amy     55     57    112   NaN
# 11277       1      2,339  Christina     50     38     88   NaN
# 14677       2      6,299      Karen     50     38     88   NaN
# 16505       4     17,626       Leo:     85      8     93   NaN
# 17914       3      5,196      Tyler      6      0      6  35.0
# 17916       1      1,067      James    300      6      9  None
# 17918       3     20,001      Renee      7    300     10  0.25
#
#                           Comments Showcase urlParam   ev2   ev3  ev4  \
# 10990                           C:      SS1    5614K   NaN   NaN  NaN
# 11277                           C:      SS2    5513K   NaN   NaN  NaN
# 14677  C: Through to the showcases      SS1    4263K   NaN   NaN  NaN
# 16505                           C:     SS2:    1071K   NaN   NaN  NaN
# 17914                           C:      SS1    0042K  60.0  25.0  NaN
# 17916                      C: 0.90      SS2    0042K  None   NaN  NaN
# 17918    C: 1.00 Bonus Spin = 0.25      SS2    0042K  None   NaN  NaN
#
#        ContestantOrder      CommNums Total_test
# 10990              2.0            []        112
# 11277              1.0            []         85
# 14677              2.0            []         85
# 16505              3.0            []        165
# 17914              2.0            []         06
# 17916              1.0        [0.90]        090
# 17918              3.0  [1.00, 0.25]        100

# %%
# One last fix
sc_df['FixMe'] = np.select([(sc_df.Spin1 > 100) | (sc_df.Spin2 > 100) | (sc_df.Spin1 % 5 != 0) | (sc_df.Spin2 % 5 != 0)],
                           [True], False)
sc_df[sc_df.FixMe]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 10990       2      8,892        Amy     55     57    112   NaN
# 11277       1      2,339  Christina     50     38     88   NaN
# 14677       2      6,299      Karen     50     38     88   NaN
# 15709       2      5,668    Tamera:    300     45     48  None
# 16500       1      1,070   Yolanda:     15    400     19   NaN
# 16505       4     17,626       Leo:     85      8     93   NaN
# 17494       2      5,319     Angela    200      0      2  15.0
# 17914       3      5,196      Tyler      6      0      6  35.0
# 17916       1      1,067      James    300      6      9  None
# 17918       3     20,001      Renee      7    300     10  0.25
#
#                                      Comments Showcase urlParam   ev2   ev3  \
# 10990                                      C:      SS1    5614K   NaN   NaN
# 11277                                      C:      SS2    5513K   NaN   NaN
# 14677             C: Through to the showcases      SS1    4263K   NaN   NaN
# 15709  C: 0.75 advances to the Showcase Round     SS2:    1401K  None   NaN
# 16500             C: Through to the Showcases     SS1:    1071K   NaN   NaN
# 16505                                      C:     SS2:    1071K   NaN   NaN
# 17494                                  C: + =      SS1    0355K  20.0  45.0
# 17914                                      C:      SS1    0042K  60.0  25.0
# 17916                                 C: 0.90      SS2    0042K  None   NaN
# 17918               C: 1.00 Bonus Spin = 0.25      SS2    0042K  None   NaN
#
#        ev4  ContestantOrder      CommNums Total_test  FixMe
# 10990  NaN              2.0            []        112   True
# 11277  NaN              1.0            []         85   True
# 14677  NaN              2.0            []         85   True
# 15709  NaN              2.0        [0.75]        075   True
# 16500  NaN              1.0            []        055   True
# 16505  NaN              3.0            []        165   True
# 17494  NaN              2.0            []          2   True
# 17914  NaN              2.0            []         06   True
# 17916  NaN              1.0        [0.90]        090   True
# 17918  NaN              3.0  [1.00, 0.25]        100   True

# %%
sc_df['Spin1'] = np.select([sc_df.FixMe & (sc_df.Spin1 > 100), sc_df.FixMe & (sc_df.Spin1 < 10)],
                          [sc_df.Spin1 / 10, sc_df.Spin1 * 10], sc_df.Spin1)
sc_df['Spin2'] = np.select([sc_df.FixMe & (sc_df.Spin2 > 100), sc_df.FixMe & (sc_df.Spin2 < 10)],
                          [sc_df.Spin2 / 10, sc_df.Spin2 * 10], sc_df.Spin2)
sc_df['FixMe'] = np.select([(sc_df.Spin1 > 100) | (sc_df.Spin2 > 100) | (sc_df.Spin1 % 5 != 0) | (sc_df.Spin2 % 5 != 0)],
                           [True], False)
sc_df[sc_df.FixMe]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total  ev1  \
# 10990       2      8,892        Amy   55.0   57.0    112  NaN
# 11277       1      2,339  Christina   50.0   38.0     88  NaN
# 14677       2      6,299      Karen   50.0   38.0     88  NaN
#
#                           Comments Showcase urlParam  ev2  ev3  ev4  \
# 10990                           C:      SS1    5614K  NaN  NaN  NaN
# 11277                           C:      SS2    5513K  NaN  NaN  NaN
# 14677  C: Through to the showcases      SS1    4263K  NaN  NaN  NaN
#
#        ContestantOrder CommNums Total_test  FixMe
# 10990              2.0       []        112   True
# 11277              1.0       []         85   True
# 14677              2.0       []         85   True

# %%
# Assume typo - round Down
sc_df['Spin2'] = sc_df['Spin2'] // 5 * 5

# %%
# Just going to make the total correct assuming Spin1 and Spin2 are accurate
sc_df.Total = sc_df.Spin1 + sc_df.Spin2
sc_df.Total = sc_df.Total.astype(np.int64)
del sc_df['FixMe']
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Total_test
# 0      SS1    9782K  NaN  NaN  NaN              1.0       []         85
# 1      SS1    9782K  NaN  NaN  NaN              2.0       []          1
# 2      SS1    9782K  NaN  NaN  NaN              3.0       []         70

# %% [markdown]
# ### Find SpinOff Extra Values

# %%
base_df = sc_df.copy()

# %%
sc_df = base_df.copy()

# %% [markdown]
# #### First Fix Extra values that may  contain bonus amounts

# %%
sc_df['ev1'] = sc_df.ev1.astype(float)
sc_df['ev2'] = sc_df.ev2.astype(float)
sc_df['ev3'] = sc_df.ev3.astype(float)
sc_df['ev4'] = sc_df.ev4.astype(float)

# %%
sc_df.loc[(sc_df.ev4 > 100) | (sc_df.ev4 < 1) | ((sc_df.ev4 % 5 != 0) & ~sc_df.ev4.isna())]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test]
# Index: []

# %%
sc_df.loc[(sc_df.ev3 > 100) | (sc_df.ev3 < 1) | ((sc_df.ev3 % 5 != 0) & ~sc_df.ev3.isna())]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test]
# Index: []

# %%
sc_df.loc[(sc_df.ev2 > 100) | (sc_df.ev2 < 1) | ((sc_df.ev2 % 5 != 0) & ~sc_df.ev2.isna())]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 1260        2      1,499     Robert   85.0    0.0     85   1.0
# 2273        4      1,799    Anthony   60.0   10.0     70   1.0
# 2345        4     12,866    Marilyn   80.0    0.0     80  90.0
# 15707       4     14,360     Ralph:    5.0   25.0     30   1.0
# 17040       1      4,598       Todd   50.0   50.0    100   5.0
# 17043       1      4,738     Milton  100.0    0.0    100  15.0
# 17881       2      7,337     Alicia  100.0    0.0    100  15.0
# 19331       4      3,811       Joan   90.0    0.0     90   1.0
# 22075       3      1,049        Jan   55.0   25.0     80  55.0
# 22823       4      5,141    Stephen   50.0    0.0     50  45.0
#
#                                      Comments     Showcase urlParam     ev2  \
# 1260   C: 1.00 Bonus Spin ► 1.00 25,000 Bonus          SS1    9333K     1.0
# 2273                C: 1.00 1.00 25,000 Bonus          SS1    8942K     1.0
# 2345                     C: 1.00 Bonus Spin ►          SS2    8911K     1.0
# 15707               C: 0.75 1.00 Bonus > 0.90         SS1:    1401K     0.9
# 17040                                C: Bonus       SSB/SO    0744K  5000.0
# 17043                          C: Bonus bonus  SSSHOWDOWN:    0744K  5000.0
# 17881                                C: Bonus       SSB/SO    0091K  5000.0
# 19331  C: 1.00 Bonus Spin > 1.00 10,000 Bonus          SS1    8793D     1.0
# 22075                    C: 1.00 Bonus Spin >          SS1    5265D     1.0
# 22823                    C: 1.00 Bonus Spin >          SS1    4993D     1.0
#
#         ev3  ev4  ContestantOrder            CommNums Total_test
# 1260    NaN  NaN              1.0        [1.00, 1.00]         85
# 2273    NaN  NaN              3.0        [1.00, 1.00]         70
# 2345   25.0  NaN              3.0              [1.00]         80
# 15707   NaN  NaN              3.0  [0.75, 1.00, 0.90]        075
# 17040   NaN  NaN              1.0                  []          1
# 17043   NaN  NaN              1.0                  []          1
# 17881   NaN  NaN              2.0                  []          1
# 19331   NaN  NaN              3.0        [1.00, 1.00]         90
# 22075  20.0  NaN              2.0              [1.00]         80
# 22823  60.0  NaN              3.0              [1.00]         50

# %%
sc_df.loc[(sc_df.ev1 > 100) | (sc_df.ev1 < 1) | ((sc_df.ev1 % 5 != 0) & ~sc_df.ev1.isna())]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total     ev1  \
# 342         1      5,232    Kristen  100.0    0.0    100     1.0
# 349         3     13,086    William   65.0   20.0     85     1.0
# 369         2      1,400    Theresa  100.0    0.0    100     1.0
# 384         2      7,081      Peter  100.0    0.0    100     1.0
# 575         3     12,979      Kenya   50.0   50.0    100     1.0
# ...       ...        ...        ...    ...    ...    ...     ...
# 24187       3      3,660     Miriam   40.0   30.0     70     1.0
# 24367       3      3,660     Miriam   40.0   30.0     70     1.0
# 24494       3      5,334      Cindy  100.0    0.0    100     1.0
# 24925       3        858       Luis   15.0   85.0    100  1000.0
# 24926       4      4,752      Maria   25.0   75.0    100  1000.0
#
#                                 Comments Showcase urlParam   ev2  ev3  ev4  \
# 342    C: Bonus Spin > 1.00 25,000 Bonus      SS1    9662K   NaN  NaN  NaN
# 349                 C: 1.00 Bonus Spin >      SS1    9661K  40.0  NaN  NaN
# 369                 C: 1.00 25,000 Bonus      SS2    9653K   NaN  NaN  NaN
# 384                 C: 1.00 25,000 Bonus      SS1    9645K   NaN  NaN  NaN
# 575        C: Bonus Spin ► 1.00 *25,000*      SS1    9591K   NaN  NaN  NaN
# ...                                  ...      ...      ...   ...  ...  ...
# 24187              C: 1.00 Bonus Spin >>      SS2    4164D  40.0  NaN  NaN
# 24367               C: 1.00 Bonus Spin >      SS2    3721D  40.0  NaN  NaN
# 24494    C: Bonus Spin 1.00 10,000 Bonus      SS1    3444D   NaN  NaN  NaN
# 24925                 C: to the showcase      SS2    1581D  95.0  NaN  NaN
# 24926                           C: + 25*      SS2    1581D  15.0  NaN  NaN
#
#        ContestantOrder CommNums Total_test
# 342                1.0   [1.00]          1
# 349                2.0   [1.00]         85
# 369                1.0   [1.00]          1
# 384                1.0   [1.00]          1
# 575                3.0   [1.00]          1
# ...                ...      ...        ...
# 24187              2.0   [1.00]         70
# 24367              2.0   [1.00]         70
# 24494              3.0   [1.00]        100
# 24925              2.0       []        100
# 24926              3.0       []        100
#
# [169 rows x 16 columns]

# %%
sc_df['ev2'] = np.select([sc_df.ev2 > 100, sc_df.ev2 <= 1], [None, sc_df.ev2 * 100], sc_df.ev2)
# First those where 1000 for first dollar in ev1 fix
sc_df['FixMe'] = np.select([sc_df.ev1 > 100], [True], False)
sc_df['ev1'] = np.select([sc_df.FixMe], [sc_df.ev2], sc_df.ev1)
sc_df['ev2'] = np.select([sc_df.FixMe], [None], sc_df.ev2)
sc_df['ev1'] = np.select([sc_df.ev1 <= 1], [sc_df.ev1 * 100], sc_df.ev1)

# %%
del sc_df['FixMe']
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Total_test
# 0      SS1    9782K  NaN  NaN  NaN              1.0       []         85
# 1      SS1    9782K  NaN  NaN  NaN              2.0       []          1
# 2      SS1    9782K  NaN  NaN  NaN              3.0       []         70

# %%
sc_df.loc[(sc_df.ev1 > 100) | (sc_df.ev1 < 5) | ((sc_df.ev1 % 5 != 0) & ~sc_df.ev1.isna())]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total  ev1  \
# 13494       1        700    William   95.0    0.0     95  2.0
# 18738       1        572     Olivia   60.0   65.0    125  2.0
#
#                     Comments Showcase urlParam  ev2  ev3  ev4  \
# 13494  C: Thru teh showcasez      SS2    4675K  NaN  NaN  NaN
# 18738    C: (puny 2nd spins)      SS2    9473D  NaN  NaN  NaN
#
#        ContestantOrder CommNums Total_test
# 13494              1.0       []         95
# 18738              1.0       []         OV

# %%
sc_df.loc[(sc_df.ev2 > 100) | (sc_df.ev2 < 1) | ((sc_df.ev2 % 5 != 0) & ~sc_df.ev2.isna())]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test]
# Index: []

# %%
sc_df['ev1'] = np.select([sc_df.ev1 < 5], [None], sc_df.ev1)

# %%
sc_df.loc[(sc_df.ev1 > 100) | (sc_df.ev1 < 5) | ((sc_df.ev1 % 5 != 0) & ~sc_df.ev1.isna())]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test]
# Index: []

# %% [markdown]
# #### Find the First SpinOffs

# %%
def get_tie_df(df, col, group_cols=['urlParam', 'Showcase']):
    """Find those with the same max value in specified column"""
    sc_maxes = df.loc[~df[col].isna(), :].groupby(group_cols)[col].max().reset_index()
    new_df = df.merge(sc_maxes, how='left', on=group_cols, suffixes=("", "Max"))
    new_df[col + 'Match'] = (new_df[col + 'Max'] == df[col])
    # Count the number of those Matching the "Max"
    sc_tie_cnt = new_df.groupby(group_cols)[col + 'Match'].sum().reset_index()
    new_df = new_df.merge(sc_tie_cnt, how='left', on=group_cols, suffixes=("", "Cnt"))
    return new_df

# %%
# Find ties first
sc_df['EndVal'] = np.select([sc_df.Total > 100], [0], sc_df.Total)
sc_df = get_tie_df(sc_df, 'EndVal')
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ev2  ev3  ev4  ContestantOrder CommNums Total_test  \
# 0      SS1    9782K  NaN  NaN  NaN              1.0       []         85
# 1      SS1    9782K  NaN  NaN  NaN              2.0       []          1
# 2      SS1    9782K  NaN  NaN  NaN              3.0       []         70
#
#    EndVal  EndValMax  EndValMatch  EndValMatchCnt
# 0      85        100        False               1
# 1     100        100         True               1
# 2      70        100        False               1

# %%
print("Showcases w/o SpinOff Value: ", 
      sc_df.loc[(sc_df.EndValMatchCnt > 1) & sc_df.EndValMatch & (sc_df.ev1.isna())].urlParam.nunique())
sc_df.loc[(sc_df.EndValMatchCnt > 1) & sc_df.EndValMatch & (sc_df.ev1.isna())].head(5)
# Out:
# Showcases w/o SpinOff Value:  29
#       SC_ind PrizeValue Contestant  Spin1  Spin2  Total  ev1  \
# 2788       3      1,858   Giovanni   45.0   55.0    100  NaN
# 3418       2        988     Robbie   25.0   65.0     90  NaN
# 3419       3      2,309      Micah   15.0   75.0     90  NaN
# 4255       3      6,810    Kathryn    5.0   90.0     95  NaN
# 4597       3      1,960     Shasta   85.0    0.0     85  NaN
#
#                          Comments Showcase urlParam  ev2  ev3  ev4  \
# 2788  C: Through to the Showcases      SS2    8674K  NaN  NaN  NaN
# 3418   C: Through to the showcase      SS2    8494K  NaN  NaN  NaN
# 3419                           C:      SS2    8494K  NaN  NaN  NaN
# 4255  C: Through to the showcases      SS2    8142K  NaN  NaN  NaN
# 4597                           C:      SS1    8012K  NaN  NaN  NaN
#
#       ContestantOrder CommNums Total_test  EndVal  EndValMax  EndValMatch  \
# 2788              2.0       []         65     100        100         True
# 3418              2.0       []         90      90         90         True
# 3419              3.0       []         85      90         90         True
# 4255              2.0       []         85      95         95         True
# 4597              2.0       []         85      85         85         True
#
#       EndValMatchCnt
# 2788               2
# 3418               2
# 3419               2
# 4255               2
# 4597               2

# %%
# Will drop the have no value to extract
sc_df['SpinOff1'] = np.select([(sc_df.EndValMatch) & (sc_df.EndValMatchCnt > 1) & ~sc_df.ev1.isna()], [sc_df.ev1], None)
sc_df['SpinOff1'] = sc_df['SpinOff1'].astype(float)
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ... ev3  ev4  ContestantOrder  CommNums Total_test  \
# 0      SS1    9782K  ... NaN  NaN              1.0        []         85
# 1      SS1    9782K  ... NaN  NaN              2.0        []          1
# 2      SS1    9782K  ... NaN  NaN              3.0        []         70
#
#   EndVal  EndValMax  EndValMatch  EndValMatchCnt  SpinOff1
# 0     85        100        False               1       NaN
# 1    100        100         True               1       NaN
# 2     70        100        False               1       NaN
#
# [3 rows x 21 columns]

# %%
sc_df['Removal'] = np.select([(sc_df.EndValMatch) & (sc_df.EndValMatchCnt > 1) & sc_df.SpinOff1.isna()], [True], False)
sc_df[sc_df.Removal]
# Out:
#        SC_ind PrizeValue  Contestant  Spin1  Spin2  Total  ev1  \
# 2788        3      1,858    Giovanni   45.0   55.0    100  NaN
# 3418        2        988      Robbie   25.0   65.0     90  NaN
# 3419        3      2,309       Micah   15.0   75.0     90  NaN
# 4255        3      6,810     Kathryn    5.0   90.0     95  NaN
# 4597        3      1,960      Shasta   85.0    0.0     85  NaN
# 5797        3      7,622      Walter   55.0    5.0     60  NaN
# 10899       2        668       Brett  100.0    0.0    100  NaN
# 11673       2      1,620         Thu   40.0   55.0     95  NaN
# 11674       3      3,691      Justin   15.0   80.0     95  NaN
# 12800       4     19,373        Luke   30.0   65.0     95  NaN
# 14213       4      5,946      Audrey   60.0   25.0     85  NaN
# 14291       4     25,747        Lisa   30.0   55.0     85  NaN
# 14368       3        995        Dale   20.0   60.0     80  NaN
# 14942       4      3,399      Horace   75.0    5.0     80  NaN
# 15015       2        998   Christina   10.0   50.0     60  NaN
# 15047       4     19,203     Frances   35.0   65.0    100  NaN
# 15116       4     14,095      Karina   75.0   25.0    100  NaN
# 15464       4      8,845      Willie   90.0    0.0     90  NaN
# 15500       4     13,616      Alison   50.0   40.0     90  NaN
# 15704       4     16,110       Sarah   70.0    0.0     70  NaN
# 16154       4      9,139       Greta   55.0   30.0     85  NaN
# 16328       4     20,440      Andrew   25.0   55.0     80  NaN
# 16359       1      1,179        Sean   45.0    0.0     45  NaN
# 16361       3      7,381      Ingrid   45.0    0.0     45  NaN
# 16620       1        509     CHIBUZO   60.0    0.0     60  NaN
# 16622       3      5,690      HOWARD   35.0   25.0     60  NaN
# 16643       4      7,883       Kevin   20.0   60.0     80  NaN
# 17826       1      1,129       Tanya   90.0    0.0     90  NaN
# 19651       3      1,349       Maria   65.0    0.0     65  NaN
# 20013       1      1,050  Marguerite   80.0    0.0     80  NaN
# 20015       3     15,079      Judith   35.0   45.0     80  NaN
# 21703       3      7,823     Barbara   65.0    0.0     65  NaN
# 21704       4      8,113      Eileen   65.0    0.0     65  NaN
# 22988       4      8,798      Olivia   35.0   35.0     70  NaN
# 24428       4      1,994        Fran   85.0   10.0     95  NaN
#
#                               Comments    Showcase urlParam  ... ev4  \
# 2788       C: Through to the Showcases         SS2    8674K  ... NaN
# 3418        C: Through to the showcase         SS2    8494K  ... NaN
# 3419                                C:         SS2    8494K  ... NaN
# 4255       C: Through to the showcases         SS2    8142K  ... NaN
# 4597                                C:         SS1    8012K  ... NaN
# 5797                                C:         SS2    7552K  ... NaN
# 10899  C: 60* Through to the Showcases         SS1    5682K  ... NaN
# 11673                               C:         SS2    5351K  ... NaN
# 11674      C: Through to the Showcases         SS2    5351K  ... NaN
# 12800                               C:         SS2    4913K  ... NaN
# 14213                               C:         SS2    4413K  ... NaN
# 14291                               C:         SS2    4384K  ... NaN
# 14368      C: Through to the showcases         SS1    4355K  ... NaN
# 14942      C: Through to the showcases         SS1    4154K  ... NaN
# 15015      C: Through to the showcases         SS2    4132K  ... NaN
# 15047                               C:         SS1    4171K  ... NaN
# 15116       C: Through to the showcase         SS1    4113K  ... NaN
# 15464                          C: STAY         SS2    1505K  ... NaN
# 15500                               C:         SS1    1485K  ... NaN
# 15704                               C:        SS2:    1402K  ... NaN
# 16154                               C:         SS1    1215K  ... NaN
# 16328                               C:         SS2    1135K  ... NaN
# 16359                               C:         SS2    1123K  ... NaN
# 16361      C: Through to the Showcases         SS2    1123K  ... NaN
# 16620               C: to the showcase         SS2    1012K  ... NaN
# 16622                               C:         SS2    1012K  ... NaN
# 16643                               C:         SS1    1002K  ... NaN
# 17826                               C:        SSSO    0123K  ... NaN
# 19651                               C:        SS1:    8491D  ... NaN
# 20013                         C: STAYS         SS2    8202D  ... NaN
# 20015      C: Through to the Showcases         SS2    8202D  ... NaN
# 21703                               C:  SSShowcase    5402D  ... NaN
# 21704                               C:  SSShowcase    5402D  ... NaN
# 22988      C: Through to the Showcases         SS1    4934D  ... NaN
# 24428                               C:         SS2    3573D  ... NaN
#
#        ContestantOrder  CommNums  Total_test EndVal EndValMax  EndValMatch  \
# 2788               2.0        []          65    100       100         True
# 3418               2.0        []          90     90        90         True
# 3419               3.0        []          85     90        90         True
# 4255               2.0        []          85     95        95         True
# 4597               2.0        []          85     85        85         True
# 5797               2.0        []          70     60        60         True
# 10899              1.0        []           1    100       100         True
# 11673              1.0        []           5     95        95         True
# 11674              2.0        []          95     95        95         True
# 12800              3.0        []          50     95        95         True
# 14213              3.0        []          45     85        85         True
# 14291              3.0        []           5     85        85         True
# 14368              2.0        []          95     80        80         True
# 14942              3.0        []          85     80        80         True
# 15015              1.0        []          35     60        60         True
# 15047              3.0        []          50    100       100         True
# 15116              3.0        []          30    100       100         True
# 15464              3.0        []          90     90        90         True
# 15500              3.0        []         900     90        90         True
# 15704              3.0        []          70     70        70         True
# 16154              3.0        []          85     85        85         True
# 16328              3.0        []         800     80        80         True
# 16359              1.0        []          45     45        45         True
# 16361              3.0        []          45     45        45         True
# 16620              1.0        []          60     60        60         True
# 16622              3.0        []          55     60        60         True
# 16643              3.0        []         800     80        80         True
# 17826              1.0        []          90     90        90         True
# 19651              2.0        []          65     65        65         True
# 20013              1.0        []          80     80        80         True
# 20015              3.0        []         800     80        80         True
# 21703              2.0        []          65     65        65         True
# 21704              3.0        []          65     65        65         True
# 22988              3.0        []          55     70        70         True
# 24428              3.0        []          40     95        95         True
#
#        EndValMatchCnt  SpinOff1  Removal
# 2788                2       NaN     True
# 3418                2       NaN     True
# 3419                2       NaN     True
# 4255                2       NaN     True
# 4597                2       NaN     True
# 5797                2       NaN     True
# 10899               2       NaN     True
# 11673               2       NaN     True
# 11674               2       NaN     True
# 12800               2       NaN     True
# 14213               2       NaN     True
# 14291               2       NaN     True
# 14368               2       NaN     True
# 14942               2       NaN     True
# 15015               2       NaN     True
# 15047               2       NaN     True
# 15116               2       NaN     True
# 15464               2       NaN     True
# 15500               2       NaN     True
# 15704               2       NaN     True
# 16154               2       NaN     True
# 16328               2       NaN     True
# 16359               2       NaN     True
# 16361               2       NaN     True
# 16620               2       NaN     True
# 16622               2       NaN     True
# 16643               2       NaN     True
# 17826               2       NaN     True
# 19651               2       NaN     True
# 20013               2       NaN     True
# 20015               2       NaN     True
# 21703               2       NaN     True
# 21704               2       NaN     True
# 22988               2       NaN     True
# 24428               2       NaN     True
#
# [35 rows x 22 columns]

# %% [markdown]
# #### 2nd Spinoffs

# %%
sc_df = get_tie_df(sc_df, 'SpinOff1')
sc_df.loc[sc_df.SpinOff1MatchCnt > 1]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 45          2        627    Vanessa   10.0   85.0     95  95.0
# 46          3      2,486   Reynaldo   95.0    0.0     95  75.0
# 47          4     16,680     Ayesha   95.0    0.0     95  95.0
# 729         2      9,567      Joven   20.0   65.0     85  85.0
# 730         3     12,623       Kirk   65.0   50.0    115   NaN
# ...       ...        ...        ...    ...    ...    ...   ...
# 23839       3      2,966      Janet   40.0   65.0    105   NaN
# 23840       4      7,702       Mark    5.0   75.0     80  90.0
# 24237       2        930   Kathleen   75.0    0.0     75   NaN
# 24238       3      3,270      Randy   90.0    0.0     90  85.0
# 24239       4      4,284        Joe   90.0    0.0     90  85.0
#
#                           Comments Showcase urlParam  ... Total_test  EndVal  \
# 45     C: Through to the Showcases      SS2    9763K  ...         95      95
# 46                              C:      SS2    9763K  ...         95      95
# 47                              C:      SS2    9763K  ...         95      95
# 729    C: Through to the Showcases      SS2    9531K  ...         85      85
# 730                             C:      SS2    9531K  ...        115       0
# ...                            ...      ...      ...  ...        ...     ...
# 23839                           C:      SS2    4622D  ...       1050       0
# 23840                           C:      SS2    4622D  ...         80      80
# 24237                           C:      SS1    3954D  ...         75      75
# 24238  C: Through to the Showcases      SS1    3954D  ...         90      90
# 24239                           C:      SS1    3954D  ...         90      90
#
#        EndValMax  EndValMatch EndValMatchCnt SpinOff1  Removal  SpinOff1Max  \
# 45            95         True              3     95.0    False         95.0
# 46            95         True              3     75.0    False         95.0
# 47            95         True              3     95.0    False         95.0
# 729           85         True              2     85.0    False         85.0
# 730           85        False              2      NaN    False         85.0
# ...          ...          ...            ...      ...      ...          ...
# 23839         80        False              2      NaN    False         90.0
# 23840         80         True              2     90.0    False         90.0
# 24237         90        False              2      NaN    False         85.0
# 24238         90         True              2     85.0    False         85.0
# 24239         90         True              2     85.0    False         85.0
#
#        SpinOff1Match  SpinOff1MatchCnt
# 45              True                 2
# 46             False                 2
# 47              True                 2
# 729             True                 2
# 730            False                 2
# ...              ...               ...
# 23839          False                 2
# 23840           True                 2
# 24237          False                 2
# 24238           True                 2
# 24239           True                 2
#
# [168 rows x 25 columns]

# %%
sc_df.loc[sc_df.SpinOff1MatchCnt > 1, :].urlParam.nunique()
# Out:
# 56

# %%
sc_df.loc[(sc_df.SpinOff1MatchCnt > 1) & (sc_df.SpinOff1Match)]
# Out:
#        SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1  \
# 45          2        627    Vanessa   10.0   85.0     95  95.0
# 47          4     16,680     Ayesha   95.0    0.0     95  95.0
# 729         2      9,567      Joven   20.0   65.0     85  85.0
# 731         4     19,496      Kayla   40.0   45.0     85  85.0
# 853         3      2,400    Gustave   95.0    0.0     95  20.0
# ...       ...        ...        ...    ...    ...    ...   ...
# 23399       4      3,016    Beverly   90.0    0.0     90  75.0
# 23838       2        350   Patricia   55.0   25.0     80  90.0
# 23840       4      7,702       Mark    5.0   75.0     80  90.0
# 24238       3      3,270      Randy   90.0    0.0     90  85.0
# 24239       4      4,284        Joe   90.0    0.0     90  85.0
#
#                           Comments Showcase urlParam  ... Total_test  EndVal  \
# 45     C: Through to the Showcases      SS2    9763K  ...         95      95
# 47                              C:      SS2    9763K  ...         95      95
# 729    C: Through to the Showcases      SS2    9531K  ...         85      85
# 731                             C:      SS2    9531K  ...         85      85
# 853                             C:      SS2    9482K  ...         95      95
# ...                            ...      ...      ...  ...        ...     ...
# 23399  C: Through to the Showcases      SS2    4783D  ...         90      90
# 23838  C: Through to the Showcases      SS2    4622D  ...         80      80
# 23840                           C:      SS2    4622D  ...         80      80
# 24238  C: Through to the Showcases      SS1    3954D  ...         90      90
# 24239                           C:      SS1    3954D  ...         90      90
#
#        EndValMax  EndValMatch EndValMatchCnt SpinOff1  Removal  SpinOff1Max  \
# 45            95         True              3     95.0    False         95.0
# 47            95         True              3     95.0    False         95.0
# 729           85         True              2     85.0    False         85.0
# 731           85         True              2     85.0    False         85.0
# 853           95         True              2     20.0    False         20.0
# ...          ...          ...            ...      ...      ...          ...
# 23399         90         True              2     75.0    False         75.0
# 23838         80         True              2     90.0    False         90.0
# 23840         80         True              2     90.0    False         90.0
# 24238         90         True              2     85.0    False         85.0
# 24239         90         True              2     85.0    False         85.0
#
#        SpinOff1Match  SpinOff1MatchCnt
# 45              True                 2
# 47              True                 2
# 729             True                 2
# 731             True                 2
# 853             True                 2
# ...              ...               ...
# 23399           True                 2
# 23838           True                 2
# 23840           True                 2
# 24238           True                 2
# 24239           True                 2
#
# [112 rows x 25 columns]

# %%
sc_df.loc[(sc_df.SpinOff1MatchCnt > 1) & (sc_df.SpinOff1Match) & (sc_df.ev2.isna())]
# Out:
# Empty DataFrame
# Columns: [SC_ind, PrizeValue, Contestant, Spin1, Spin2, Total, ev1, Comments, Showcase, urlParam, ev2, ev3, ev4, ContestantOrder, CommNums, Total_test, EndVal, EndValMax, EndValMatch, EndValMatchCnt, SpinOff1, Removal, SpinOff1Max, SpinOff1Match, SpinOff1MatchCnt]
# Index: []
#
# [0 rows x 25 columns]

# %%
sc_df['SpinOff2'] = np.select([(sc_df.SpinOff1MatchCnt > 1) & (sc_df.SpinOff1Match)], [sc_df.ev2], None)
sc_df['SpinOff2'] = sc_df.SpinOff2.astype(float)

# %%
display_cols = ['Contestant', 'Spin1', 'Spin2', 'Total', 'ev1', 'Comments', 'Showcase', 'urlParam', 'ev2', 'ev3', 'ev4',
                'ContestantOrder', 'CommNums', 'Total_test', 'SpinOff1', 'Removal', 'SpinOff2']
sc_df.loc[~sc_df.SpinOff2.isna(), display_cols]
# Out:
#       Contestant  Spin1  Spin2  Total   ev1                     Comments  \
# 45       Vanessa   10.0   85.0     95  95.0  C: Through to the Showcases
# 47        Ayesha   95.0    0.0     95  95.0                           C:
# 729        Joven   20.0   65.0     85  85.0  C: Through to the Showcases
# 731        Kayla   40.0   45.0     85  85.0                           C:
# 853      Gustave   95.0    0.0     95  20.0                           C:
# ...          ...    ...    ...    ...   ...                          ...
# 23399    Beverly   90.0    0.0     90  75.0  C: Through to the Showcases
# 23838   Patricia   55.0   25.0     80  90.0  C: Through to the Showcases
# 23840       Mark    5.0   75.0     80  90.0                           C:
# 24238      Randy   90.0    0.0     90  85.0  C: Through to the Showcases
# 24239        Joe   90.0    0.0     90  85.0                           C:
#
#       Showcase urlParam   ev2  ev3  ev4  ContestantOrder CommNums Total_test  \
# 45         SS2    9763K  85.0  NaN  NaN              1.0       []         95
# 47         SS2    9763K  45.0  NaN  NaN              3.0       []         95
# 729        SS2    9531K  60.0  NaN  NaN              1.0       []         85
# 731        SS2    9531K  15.0  NaN  NaN              3.0       []         85
# 853        SS2    9482K  20.0  NaN  NaN              2.0       []         95
# ...        ...      ...   ...  ...  ...              ...      ...        ...
# 23399      SS2    4783D  25.0  NaN  NaN              3.0       []         90
# 23838      SS2    4622D  95.0  NaN  NaN              1.0       []         80
# 23840      SS2    4622D  70.0  NaN  NaN              3.0       []         80
# 24238      SS1    3954D  45.0  NaN  NaN              2.0       []         90
# 24239      SS1    3954D  25.0  NaN  NaN              3.0       []         90
#
#        SpinOff1  Removal  SpinOff2
# 45         95.0    False      85.0
# 47         95.0    False      45.0
# 729        85.0    False      60.0
# 731        85.0    False      15.0
# 853        20.0    False      20.0
# ...         ...      ...       ...
# 23399      75.0    False      25.0
# 23838      90.0    False      95.0
# 23840      90.0    False      70.0
# 24238      85.0    False      45.0
# 24239      85.0    False      25.0
#
# [112 rows x 17 columns]

# %% [markdown]
# #### SpinOff3

# %%
sc_df.head(3)
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ... EndVal  EndValMax  EndValMatch  EndValMatchCnt  \
# 0      SS1    9782K  ...     85        100        False               1
# 1      SS1    9782K  ...    100        100         True               1
# 2      SS1    9782K  ...     70        100        False               1
#
#   SpinOff1 Removal  SpinOff1Max  SpinOff1Match  SpinOff1MatchCnt  SpinOff2
# 0      NaN   False          NaN          False                 0       NaN
# 1      NaN   False          NaN          False                 0       NaN
# 2      NaN   False          NaN          False                 0       NaN
#
# [3 rows x 26 columns]

# %%
sc_df = get_tie_df(sc_df, 'SpinOff2')

# %%
sc_df.loc[(sc_df.SpinOff2MatchCnt.astype(float) > 1) & sc_df.SpinOff2Match, display_cols]
# Out:
#       Contestant  Spin1  Spin2  Total   ev1  \
# 13141    Mildred   35.0   60.0     95  30.0
# 13142     Mccall   95.0    0.0     95  30.0
# 13999     Daniel   95.0    0.0     95  50.0
# 14000       Vito   80.0   15.0     95  50.0
# 16540     Daniel    5.0   80.0     85  10.0
# 16541      Jaime   50.0   35.0     85  10.0
# 16794      Trina   75.0    0.0     75  25.0
# 16796       Mary   75.0    0.0     75  25.0
# 17752     Rafael   85.0    0.0     85  40.0
# 17753    Melissa   85.0    0.0     85  40.0
# 17914      Tyler   60.0    0.0     60  35.0
# 17915    Jeffrey   55.0    5.0     60  35.0
# 20653       Jeff   45.0   35.0     80  15.0
# 20654      Edgar   50.0   30.0     80  15.0
#
#                                          Comments Showcase urlParam   ev2  \
# 13141                 C: Through to the Showcases      SS2    4801K  20.0
# 13142                                          C:      SS2    4801K  20.0
# 13999                                          C:      SS1    4494K   5.0
# 14000                       C: Through...FINALLY!      SS1    4494K   5.0
# 16540                 C: Through to the Showcases      SS2    1051K  50.0
# 16541                                          C:      SS2    1051K  50.0
# 16794                 C: Through to the Showcases      SS2    0925K  65.0
# 16796                                          C:      SS2    0925K  65.0
# 17752                                          C:     SSSO    0222K  10.0
# 17753                          C: to the showacse     SSSO    0222K  10.0
# 17914                                          C:      SS1    0042K  60.0
# 17915  C: 0.60 Jeffrey FINALLY goes to Showcase!!      SS1    0042K  60.0
# 20653                                          C:      SS2    6513D  60.0
# 20654                                          C:      SS2    6513D  60.0
#
#         ev3  ev4  ContestantOrder CommNums Total_test  SpinOff1  Removal  \
# 13141  90.0  NaN              2.0       []         95      30.0    False
# 13142  85.0  NaN              3.0       []         95      30.0    False
# 13999  20.0  NaN              2.0       []         95      50.0    False
# 14000  80.0  NaN              3.0       []         95      50.0    False
# 16540  95.0  NaN              2.0       []        850      10.0    False
# 16541  10.0  NaN              3.0       []        850      10.0    False
# 16794  95.0  NaN              1.0       []         75      25.0    False
# 16796  45.0  NaN              3.0       []         75      25.0    False
# 17752  30.0  NaN              2.0       []         85      40.0    False
# 17753  85.0  NaN              3.0       []         85      40.0    False
# 17914  25.0  NaN              2.0       []         06      35.0    False
# 17915  45.0  NaN              3.0   [0.60]        060      35.0    False
# 20653  60.0  NaN              2.0       []         80      15.0    False
# 20654  75.0  NaN              3.0       []         80      15.0    False
#
#        SpinOff2
# 13141      20.0
# 13142      20.0
# 13999       5.0
# 14000       5.0
# 16540      50.0
# 16541      50.0
# 16794      65.0
# 16796      65.0
# 17752      10.0
# 17753      10.0
# 17914      60.0
# 17915      60.0
# 20653      60.0
# 20654      60.0

# %%
sc_df['SpinOff3'] = np.select([(sc_df.SpinOff2MatchCnt > 1) & (sc_df.SpinOff2Match)], [sc_df.ev3], None)
sc_df['SpinOff3'] = sc_df.SpinOff3.astype(float)

# %%
sc_df.loc[(sc_df.SpinOff2MatchCnt.astype(float) > 1) & sc_df.SpinOff2Match, display_cols + ['SpinOff3']]
# Out:
#       Contestant  Spin1  Spin2  Total   ev1  \
# 13141    Mildred   35.0   60.0     95  30.0
# 13142     Mccall   95.0    0.0     95  30.0
# 13999     Daniel   95.0    0.0     95  50.0
# 14000       Vito   80.0   15.0     95  50.0
# 16540     Daniel    5.0   80.0     85  10.0
# 16541      Jaime   50.0   35.0     85  10.0
# 16794      Trina   75.0    0.0     75  25.0
# 16796       Mary   75.0    0.0     75  25.0
# 17752     Rafael   85.0    0.0     85  40.0
# 17753    Melissa   85.0    0.0     85  40.0
# 17914      Tyler   60.0    0.0     60  35.0
# 17915    Jeffrey   55.0    5.0     60  35.0
# 20653       Jeff   45.0   35.0     80  15.0
# 20654      Edgar   50.0   30.0     80  15.0
#
#                                          Comments Showcase urlParam   ev2  \
# 13141                 C: Through to the Showcases      SS2    4801K  20.0
# 13142                                          C:      SS2    4801K  20.0
# 13999                                          C:      SS1    4494K   5.0
# 14000                       C: Through...FINALLY!      SS1    4494K   5.0
# 16540                 C: Through to the Showcases      SS2    1051K  50.0
# 16541                                          C:      SS2    1051K  50.0
# 16794                 C: Through to the Showcases      SS2    0925K  65.0
# 16796                                          C:      SS2    0925K  65.0
# 17752                                          C:     SSSO    0222K  10.0
# 17753                          C: to the showacse     SSSO    0222K  10.0
# 17914                                          C:      SS1    0042K  60.0
# 17915  C: 0.60 Jeffrey FINALLY goes to Showcase!!      SS1    0042K  60.0
# 20653                                          C:      SS2    6513D  60.0
# 20654                                          C:      SS2    6513D  60.0
#
#         ev3  ev4  ContestantOrder CommNums Total_test  SpinOff1  Removal  \
# 13141  90.0  NaN              2.0       []         95      30.0    False
# 13142  85.0  NaN              3.0       []         95      30.0    False
# 13999  20.0  NaN              2.0       []         95      50.0    False
# 14000  80.0  NaN              3.0       []         95      50.0    False
# 16540  95.0  NaN              2.0       []        850      10.0    False
# 16541  10.0  NaN              3.0       []        850      10.0    False
# 16794  95.0  NaN              1.0       []         75      25.0    False
# 16796  45.0  NaN              3.0       []         75      25.0    False
# 17752  30.0  NaN              2.0       []         85      40.0    False
# 17753  85.0  NaN              3.0       []         85      40.0    False
# 17914  25.0  NaN              2.0       []         06      35.0    False
# 17915  45.0  NaN              3.0   [0.60]        060      35.0    False
# 20653  60.0  NaN              2.0       []         80      15.0    False
# 20654  75.0  NaN              3.0       []         80      15.0    False
#
#        SpinOff2  SpinOff3
# 13141      20.0      90.0
# 13142      20.0      85.0
# 13999       5.0      20.0
# 14000       5.0      80.0
# 16540      50.0      95.0
# 16541      50.0      10.0
# 16794      65.0      95.0
# 16796      65.0      45.0
# 17752      10.0      30.0
# 17753      10.0      85.0
# 17914      60.0      25.0
# 17915      60.0      45.0
# 20653      60.0      60.0
# 20654      60.0      75.0

# %% [markdown]
# ### Bonus Spin Value if spun 100
# Beginning on December 12, 1978, hitting \$1.00 not only won the \$1,000, but also a bonus spin

# %%
new_base = sc_df.copy()

# %%
# Find first value of 100 and then take the next value as the Bonus
sc_df['Bonus'] = np.select([sc_df.Total == 100, sc_df.SpinOff1 == 100, sc_df.SpinOff2 == 100],
                          [sc_df.ev1, sc_df.ev2, sc_df.ev3], None)
sc_df.loc[sc_df.SpinOff2 == 100, display_cols + ['SpinOff3', 'Bonus']]
# Out:
#         Contestant  Spin1  Spin2  Total    ev1                       Comments  \
# 2273       Anthony   60.0   10.0     70  100.0      C: 1.00 1.00 25,000 Bonus
# 2345       Marilyn   80.0    0.0     80   90.0           C: 1.00 Bonus Spin ►
# 15453  Christopher   45.0   45.0     90   55.0                  C: bonus spin
# 16717      Beverly  100.0    0.0    100  100.0  C: *1,000* BONUS ***10,000***
# 19446       Rodney   90.0    0.0     90   90.0               C: *1,000* BONUS
# 22075          Jan   55.0   25.0     80   55.0           C: 1.00 Bonus Spin >
# 22823      Stephen   50.0    0.0     50   45.0           C: 1.00 Bonus Spin >
#
#       Showcase urlParam    ev2   ev3  ev4  ContestantOrder      CommNums  \
# 2273       SS1    8942K  100.0   NaN  NaN              3.0  [1.00, 1.00]
# 2345       SS2    8911K  100.0  25.0  NaN              3.0        [1.00]
# 15453      SS1    1511K  100.0  95.0  NaN              1.0            []
# 16717      SS2    0972K  100.0   NaN  NaN              2.0            []
# 19446      SS2    8704D  100.0  10.0  NaN              1.0            []
# 22075      SS1    5265D  100.0  20.0  NaN              2.0        [1.00]
# 22823      SS1    4993D  100.0  60.0  NaN              3.0        [1.00]
#
#       Total_test  SpinOff1  Removal  SpinOff2  SpinOff3  Bonus
# 2273          70     100.0    False     100.0       NaN  100.0
# 2345          80      90.0    False     100.0       NaN   25.0
# 15453        900      55.0    False     100.0       NaN   95.0
# 16717        100     100.0    False     100.0       NaN  100.0
# 19446         90      90.0    False     100.0       NaN   10.0
# 22075         80      55.0    False     100.0       NaN   20.0
# 22823         50      45.0    False     100.0       NaN   60.0

# %% [markdown]
# ### Final Removal of Bad Data & Combine with Content

# %%
print(sc_df.shape)
sc_df = sc_df.loc[~sc_df.Removal].copy()
del sc_df['Removal']
sc_df.shape
# Out:
# (24933, 31)
# (24898, 30)

# %%
sc_df = keep_only_with_three(sc_df)
sc_df.shape
# Out:
# 3    0.996511
# 2    0.002767
# 1    0.000722
# Name: SC_ind, dtype: float64
# (24846, 30)

# %% [markdown]
# #### Winner Column

# %%
sc_df = get_tie_df(sc_df, 'SpinOff3')

# %%
sc_df['Winner'] = np.select([sc_df.SpinOff3Match, sc_df.SpinOff3Max.isna() & sc_df.SpinOff2Match,
                             sc_df.SpinOff2Max.isna() & sc_df.SpinOff1Match, sc_df.SpinOff1Max.isna() & sc_df.EndValMatch],
                            [True, True,  True, True], False)
sc_df.groupby(['Showcase', 'urlParam']).Winner.sum().reset_index().Winner.value_counts()
# Out:
# 1    8282
# Name: Winner, dtype: int64

# %%
sc_df.columns
# Out:
# Index(['SC_ind', 'PrizeValue', 'Contestant', 'Spin1', 'Spin2', 'Total', 'ev1',
#        'Comments', 'Showcase', 'urlParam', 'ev2', 'ev3', 'ev4',
#        'ContestantOrder', 'CommNums', 'Total_test', 'EndVal', 'EndValMax',
#        'EndValMatch', 'EndValMatchCnt', 'SpinOff1', 'SpinOff1Max',
#        'SpinOff1Match', 'SpinOff1MatchCnt', 'SpinOff2', 'SpinOff2Max',
#        'SpinOff2Match', 'SpinOff2MatchCnt', 'SpinOff3', 'Bonus', 'SpinOff3Max',
#        'SpinOff3Match', 'SpinOff3MatchCnt', 'Winner'],
#       dtype='object')

# %% [markdown]
# #### Final Merge

# %%
display(sc_df.head(3))
display(main_df.head(3))
# Out:
#    SC_ind PrizeValue Contestant  Spin1  Spin2  Total   ev1         Comments  \
# 0       1      1,340    Maurice   85.0    0.0     85   NaN               C:
# 1       2      8,531        Kim  100.0    0.0    100  50.0  C: Bonus Spin ►
# 2       3     25,760     Sandra   20.0   50.0     70   NaN               C:
#
#   Showcase urlParam  ... SpinOff2  SpinOff2Max  SpinOff2Match  \
# 0      SS1    9782K  ...      NaN          NaN          False
# 1      SS1    9782K  ...      NaN          NaN          False
# 2      SS1    9782K  ...      NaN          NaN          False
#
#    SpinOff2MatchCnt SpinOff3 Bonus  SpinOff3Max  SpinOff3Match  \
# 0                 0      NaN  None          NaN          False
# 1                 0      NaN  50.0          NaN          False
# 2                 0      NaN  None          NaN          False
#
#    SpinOff3MatchCnt  Winner
# 0                 0   False
# 1                 0    True
# 2                 0   False
#
# [3 rows x 34 columns]
#                                  url episodeID  errorCode  \
# 0   https://tpirepguide.com/?p=18052     9782K          0
# 10  https://tpirepguide.com/?p=18045     9781K          0
# 11  https://tpirepguide.com/?p=18018     9775K          0
#
#                                       footer  urlParam EpsCategory    airDate
# 0   March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 10  March 28th, 2022 |  Category: Carey Eps      18045   Carey Eps 2022-03-28
# 11  March 25th, 2022 |  Category: Carey Eps      18018   Carey Eps 2022-03-25

# %%
final_df = main_df.merge(sc_df, how='left', left_on=['episodeID'], right_on=['urlParam'], suffixes=("", "_sc"))
final_df.head(3)
# Out:
#                                 url episodeID  errorCode  \
# 0  https://tpirepguide.com/?p=18052     9782K          0
# 1  https://tpirepguide.com/?p=18052     9782K          0
# 2  https://tpirepguide.com/?p=18052     9782K          0
#
#                                      footer  urlParam EpsCategory    airDate  \
# 0  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 1  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 2  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
#
#    SC_ind PrizeValue Contestant  ...  SpinOff2  SpinOff2Max  SpinOff2Match  \
# 0     1.0      1,340    Maurice  ...       NaN          NaN          False
# 1     2.0      8,531        Kim  ...       NaN          NaN          False
# 2     3.0     25,760     Sandra  ...       NaN          NaN          False
#
#   SpinOff2MatchCnt SpinOff3 Bonus SpinOff3Max SpinOff3Match  SpinOff3MatchCnt  \
# 0              0.0      NaN  None         NaN         False               0.0
# 1              0.0      NaN  50.0         NaN         False               0.0
# 2              0.0      NaN  None         NaN         False               0.0
#
#    Winner
# 0   False
# 1    True
# 2   False
#
# [3 rows x 41 columns]

# %%
final_df.columns
# Out:
# Index(['url', 'episodeID', 'errorCode', 'footer', 'urlParam', 'EpsCategory',
#        'airDate', 'SC_ind', 'PrizeValue', 'Contestant', 'Spin1', 'Spin2',
#        'Total', 'ev1', 'Comments', 'Showcase', 'urlParam_sc', 'ev2', 'ev3',
#        'ev4', 'ContestantOrder', 'CommNums', 'Total_test', 'EndVal',
#        'EndValMax', 'EndValMatch', 'EndValMatchCnt', 'SpinOff1', 'SpinOff1Max',
#        'SpinOff1Match', 'SpinOff1MatchCnt', 'SpinOff2', 'SpinOff2Max',
#        'SpinOff2Match', 'SpinOff2MatchCnt', 'SpinOff3', 'Bonus', 'SpinOff3Max',
#        'SpinOff3Match', 'SpinOff3MatchCnt', 'Winner'],
#       dtype='object')

# %%
final_df.loc[:, ['url', 'episodeID', 'errorCode', 'footer', 'urlParam', 'EpsCategory',
       'airDate', 'SC_ind', 'PrizeValue', 'Contestant', 'Spin1', 'Spin2',
       'Total', 'Comments', 'Showcase', 'ev1', 'ev2', 'ev3',
       'ev4', 'ContestantOrder', 'CommNums', 'Total_test', 'EndVal',
       'EndValMax', 'EndValMatch', 'EndValMatchCnt', 'SpinOff1', 'SpinOff1Max',
       'SpinOff1Match', 'SpinOff1MatchCnt', 'SpinOff2', 'SpinOff2Max',
       'SpinOff2Match', 'SpinOff2MatchCnt', 'SpinOff3', 'SpinOff3Max',
       'SpinOff3Match', 'SpinOff3MatchCnt', 'Bonus', 'Winner']].to_csv(r"FullContent.csv", header=True, index=False)

# %%
main_df.loc[main_df.episodeID == '4675K']

# %% [markdown]
# ### Create CrossTab w/ all 3 contestants in 1 Row

# %%
file_path = r"FullContent.csv"
df = pd.read_csv(file_path, parse_dates=['airDate']).drop_duplicates()
df.head(3)
# Out:
#                                 url episodeID  errorCode  \
# 0  https://tpirepguide.com/?p=18052     9782K          0
# 1  https://tpirepguide.com/?p=18052     9782K          0
# 2  https://tpirepguide.com/?p=18052     9782K          0
#
#                                      footer  urlParam EpsCategory    airDate  \
# 0  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 1  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
# 2  March 29th, 2022 |  Category: Carey Eps      18052   Carey Eps 2022-03-29
#
#    SC_ind PrizeValue Contestant  ...  SpinOff2  SpinOff2Max  SpinOff2Match  \
# 0     1.0      1,340    Maurice  ...       NaN          NaN          False
# 1     2.0      8,531        Kim  ...       NaN          NaN          False
# 2     3.0     25,760     Sandra  ...       NaN          NaN          False
#
#   SpinOff2MatchCnt SpinOff3  SpinOff3Max  SpinOff3Match  SpinOff3MatchCnt  \
# 0              0.0      NaN          NaN          False               0.0
# 1              0.0      NaN          NaN          False               0.0
# 2              0.0      NaN          NaN          False               0.0
#
#    Bonus  Winner
# 0    NaN   False
# 1   50.0    True
# 2    NaN   False
#
# [3 rows x 40 columns]

# %%
df = df.loc[~df.ContestantOrder.isna()].copy()
df.shape
# Out:
# (24864, 40)

# %%
remove_cols = ['ev1', 'ev2', 'ev3', 'ev4', 'SC_ind', 'footer', 'Comments', 'Total_test', 'CommNums']
for c in remove_cols:
    del df[c]
df['Spin1'] = df['Spin1'].astype(np.int64)
df['Spin2'] = df['Spin2'].astype(np.int64)
df['Total'] = df['Total'].astype(np.int64)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24864 entries, 0 to 26790
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               24864 non-null  object
#  1   episodeID         24864 non-null  object
#  2   errorCode         24864 non-null  int64
#  3   urlParam          24864 non-null  int64
#  4   EpsCategory       24864 non-null  object
#  5   airDate           24864 non-null  datetime64[ns]
#  6   PrizeValue        24864 non-null  object
#  7   Contestant        24864 non-null  object
#  8   Spin1             24864 non-null  int64
#  9   Spin2             24864 non-null  int64
#  10  Total             24864 non-null  int64
#  11  Showcase          24864 non-null  object
#  12  ContestantOrder   24864 non-null  float64
#  13  EndVal            24864 non-null  float64
#  14  EndValMax         24864 non-null  float64
#  15  EndValMatch       24864 non-null  object
#  16  EndValMatchCnt    24864 non-null  float64
#  17  SpinOff1          1999 non-null   float64
#  18  SpinOff1Max       2919 non-null   float64
#  19  SpinOff1Match     24864 non-null  object
#  20  SpinOff1MatchCnt  24864 non-null  float64
#  21  SpinOff2          112 non-null    float64
#  22  SpinOff2Max       168 non-null    float64
#  23  SpinOff2Match     24864 non-null  object
#  24  SpinOff2MatchCnt  24864 non-null  float64
#  25  SpinOff3          14 non-null     float64
#  26  SpinOff3Max       21 non-null     float64
#  27  SpinOff3Match     24864 non-null  object
#  28  SpinOff3MatchCnt  24864 non-null  float64
#  29  Bonus             2007 non-null   float64
#  30  Winner            24864 non-null  object
# dtypes: datetime64[ns](1), float64(14), int64(5), object(11)
# memory usage: 6.1+ MB

# %%
other_cols = ['urlParam', 'Showcase', 'PrizeValue', 'Contestant', 'Spin1', 'Spin2', 'Total',
              'EndValMatch', 'SpinOff1', 'SpinOff2', 'SpinOff3', 'Bonus', 'Winner']
c1_df = df.loc[(df.ContestantOrder == 1)].copy()
c2_df = df.loc[(df.ContestantOrder == 2), other_cols].copy()
c3_df = df.loc[(df.ContestantOrder == 3), other_cols].copy()
print(c1_df.shape, c2_df.shape, c3_df.shape)
# Out:
# (8288, 31) (8288, 13) (8288, 13)

# %% [markdown]
# Merge

# %%
ct_df = c1_df.merge(c2_df, how='left', on=['urlParam', 'Showcase'], suffixes=("", '_C2'))
ct_df = ct_df.merge(c3_df, how='left', on=['urlParam', 'Showcase'], suffixes=("", '_C3'))
ct_df.shape
# Out:
# (8288, 53)

# %%
ct_df.columns
# Out:
# Index(['url', 'episodeID', 'errorCode', 'urlParam', 'EpsCategory', 'airDate',
#        'PrizeValue', 'Contestant', 'Spin1', 'Spin2', 'Total', 'Showcase',
#        'ContestantOrder', 'EndVal', 'EndValMax', 'EndValMatch',
#        'EndValMatchCnt', 'SpinOff1', 'SpinOff1Max', 'SpinOff1Match',
#        'SpinOff1MatchCnt', 'SpinOff2', 'SpinOff2Max', 'SpinOff2Match',
#        'SpinOff2MatchCnt', 'SpinOff3', 'SpinOff3Max', 'SpinOff3Match',
#        'SpinOff3MatchCnt', 'Bonus', 'Winner', 'PrizeValue_C2', 'Contestant_C2',
#        'Spin1_C2', 'Spin2_C2', 'Total_C2', 'EndValMatch_C2', 'SpinOff1_C2',
#        'SpinOff2_C2', 'SpinOff3_C2', 'Bonus_C2', 'Winner_C2', 'PrizeValue_C3',
#        'Contestant_C3', 'Spin1_C3', 'Spin2_C3', 'Total_C3', 'EndValMatch_C3',
#        'SpinOff1_C3', 'SpinOff2_C3', 'SpinOff3_C3', 'Bonus_C3', 'Winner_C3'],
#       dtype='object')

# %%
ct_df['Winner'] = ct_df['Winner'].astype(bool)
ct_df['Winner_C2'] = ct_df['Winner_C2'].astype(bool)
ct_df['Winner_C3'] = ct_df['Winner_C3'].astype(bool)
ct_df['winnerNum'] = np.select([ct_df.Winner, ct_df.Winner_C2, ct_df.Winner_C3], [1, 2, 3], None)
ct_df.winnerNum.value_counts()
# Out:
# 3    2955
# 2    2831
# 1    2502
# Name: winnerNum, dtype: int64

# %%
# Add Result for Flow Diagram later
# C1 --> Over or Stays
ct_df['C1_Result'] = np.select([ct_df.Total > 100], ['Over'], 'Stay')
ct_df.groupby(['C1_Result'])['Total'].agg(['count', 'min', 'max']).reset_index()
# Out:
#   C1_Result  count  min  max
# 0      Over   1711  105  165
# 1      Stay   6577   10  100

# %%
# C2 --> Over, Ties, Stays, Under
ct_df['C2_Result'] = np.select([ct_df.Total_C2 > 100, ct_df.C1_Result == 'Over',
                                ct_df.Total_C2 < ct_df.Total, ct_df.Total_C2 == ct_df.Total],
                              ['Over', 'Stay', 'Under', 'Tie'], 'Stay')

# %%
ct_df.groupby(['C1_Result', 'C2_Result'])[['Total', 'Total_C2']].agg(['count', 'min', 'max']).reset_index()
# Out:
#   C1_Result C2_Result Total           Total_C2
#                       count  min  max    count  min  max
# 0      Over      Over   272  105  160      272  105  165
# 1      Over      Stay  1439  105  165     1439   10  100
# 2      Stay      Over  1973   10  100     1973  105  195
# 3      Stay      Stay  2573   10   95     2573   30  100
# 4      Stay       Tie   528   25  100      528   25  100
# 5      Stay     Under  1503   20  100     1503   10   95

# %%
# C2 --> Over, Ties, Stays, Under
ct_df['C3_Result'] = np.select([ct_df.Total_C3 > 100, (ct_df.C1_Result == 'Over') & (ct_df.C2_Result == 'Over'),
                                (ct_df.C2_Result.isin(['Stay', 'Tie'])) & (ct_df.Total_C3 < ct_df.Total_C2),
                                (ct_df.C2_Result.isin(['Stay', 'Tie'])) & (ct_df.Total_C3 > ct_df.Total_C2),
                                (ct_df.C2_Result.isin(['Stay', 'Tie'])) & (ct_df.Total_C3 == ct_df.Total_C2),
                                (ct_df.C2_Result.isin(['Over', 'Under'])) & (ct_df.Total_C3 < ct_df.Total),
                                (ct_df.C2_Result.isin(['Over', 'Under'])) & (ct_df.Total_C3 > ct_df.Total),
                                (ct_df.C2_Result.isin(['Over', 'Under'])) & (ct_df.Total_C3 == ct_df.Total)],
                               ['Over', 'Stay', 'Under', 'Stay', 'Tie', 'Under', 'Stay', 'Tie'], 'Unknown')

# %%
ct_df.groupby(['C1_Result', 'C2_Result', 'C3_Result'])[['Total', 'Total_C2',
                                                        'Total_C3']].agg(['count', 'min', 'max']).reset_index()
# Out:
#    C1_Result C2_Result C3_Result Total           Total_C2           Total_C3  \
#                                  count  min  max    count  min  max    count
# 0       Over      Over      Stay   272  105  160      272  105  165      272
# 1       Over      Stay      Over   395  105  165      395   30  100      395
# 2       Over      Stay      Stay   597  105  165      597   10   95      597
# 3       Over      Stay       Tie   108  105  165      108   40  100      108
# 4       Over      Stay     Under   339  105  160      339   35  100      339
# 5       Stay      Over      Over   645   40  100      645  105  190      645
# 6       Stay      Over      Stay   608   10   95      608  105  190      608
# 7       Stay      Over       Tie   162   50  100      162  105  180      162
# 8       Stay      Over     Under   558   15  100      558  105  195      558
# 9       Stay      Stay      Over   919   10   95      919   50  100      919
# 10      Stay      Stay      Stay   598   10   90      598   30   95      598
# 11      Stay      Stay       Tie   220   10   95      220   30  100      220
# 12      Stay      Stay     Under   836   10   95      836   55  100      836
# 13      Stay       Tie      Over   169   50  100      169   50  100      169
# 14      Stay       Tie      Stay   164   25   95      164   25   95      164
# 15      Stay       Tie       Tie    53   50  100       53   50  100       53
# 16      Stay       Tie     Under   142   60  100      142   60  100      142
# 17      Stay     Under      Over   530   30  100      530   15   95      530
# 18      Stay     Under      Stay   408   20   95      408   10   90      408
# 19      Stay     Under       Tie   119   45  100      119   15   95      119
# 20      Stay     Under     Under   446   35  100      446   10   95      446
#
#
#     min  max
# 0     5  100
# 1   105  190
# 2    25  100
# 3    40  100
# 4    10   95
# 5   105  195
# 6    20  100
# 7    50  100
# 8    10   95
# 9   105  195
# 10   45  100
# 11   30  100
# 12   10   95
# 13  105  185
# 14   35  100
# 15   50  100
# 16   10   95
# 17  105  190
# 18   40  100
# 19   45  100
# 20   10   95

# %%
ct_df.groupby(['C1_Result', 'C2_Result', 'C3_Result', 'winnerNum'])[['Total', 'Total_C2',
                                                        'Total_C3']].agg(['count', 'min', 'max']).reset_index()
# Out:
#    C1_Result C2_Result C3_Result winnerNum Total           Total_C2            \
#                                            count  min  max    count  min  max
# 0       Over      Over      Stay         3   272  105  160      272  105  165
# 1       Over      Stay      Over         2   395  105  165      395   30  100
# 2       Over      Stay      Stay         3   597  105  165      597   10   95
# 3       Over      Stay       Tie         2    54  105  165       54   40  100
# 4       Over      Stay       Tie         3    54  105  155       54   45  100
# 5       Over      Stay     Under         2   339  105  160      339   35  100
# 6       Stay      Over      Over         1   645   40  100      645  105  190
# 7       Stay      Over      Stay         3   608   10   95      608  105  190
# 8       Stay      Over       Tie         1    84   50  100       84  105  180
# 9       Stay      Over       Tie         3    78   50  100       78  105  175
# 10      Stay      Over     Under         1   558   15  100      558  105  195
# 11      Stay      Stay      Over         2   919   10   95      919   50  100
# 12      Stay      Stay      Stay         3   598   10   90      598   30   95
# 13      Stay      Stay       Tie         2   110   10   95      110   30  100
# 14      Stay      Stay       Tie         3   110   10   95      110   45  100
# 15      Stay      Stay     Under         2   836   10   95      836   55  100
# 16      Stay       Tie      Over         1    93   50  100       93   50  100
# 17      Stay       Tie      Over         2    76   60  100       76   60  100
# 18      Stay       Tie      Stay         3   164   25   95      164   25   95
# 19      Stay       Tie       Tie         1    22   50  100       22   50  100
# 20      Stay       Tie       Tie         2    20   50  100       20   50  100
# 21      Stay       Tie       Tie         3    11   65  100       11   65  100
# 22      Stay       Tie     Under         1    60   60  100       60   60  100
# 23      Stay       Tie     Under         2    82   60  100       82   60  100
# 24      Stay     Under      Over         1   530   30  100      530   15   95
# 25      Stay     Under      Stay         3   408   20   95      408   10   90
# 26      Stay     Under       Tie         1    64   50  100       64   15   95
# 27      Stay     Under       Tie         3    55   45  100       55   25   95
# 28      Stay     Under     Under         1   446   35  100      446   10   95
#
#    Total_C3
#       count  min  max
# 0       272    5  100
# 1       395  105  190
# 2       597   25  100
# 3        54   40  100
# 4        54   45  100
# 5       339   10   95
# 6       645  105  195
# 7       608   20  100
# 8        84   50  100
# 9        78   50  100
# 10      558   10   95
# 11      919  105  195
# 12      598   45  100
# 13      110   30  100
# 14      110   45  100
# 15      836   10   95
# 16       93  105  175
# 17       76  105  185
# 18      164   35  100
# 19       22   50  100
# 20       20   50  100
# 21       11   65  100
# 22       60   15   95
# 23       82   10   90
# 24      530  105  190
# 25      408   40  100
# 26       64   50  100
# 27       55   45  100
# 28      446   10   95

# %%
ct_df.to_csv(r"OneRowData.csv", header=True, index=False)

# %%
year_sum = final_df.groupby(['urlParam', final_df.airDate.dt.year]).ContestantOrder.count().reset_index()
year_sum['Found'] = np.select([year_sum.ContestantOrder > 0], [1], 0)
year_sum = year_sum.groupby('airDate').Found.agg(['sum', 'count']).reset_index()

# %%
year_sum
# Out:
#     airDate  sum  count
# 0      1972    0     84
# 1      1973    0     80
# 2      1974    0     30
# 3      1975    6     35
# 4      1976   17     22
# 5      1977   29     31
# 6      1978   16     18
# 7      1979   20     20
# 8      1980   33     38
# 9      1981   28     30
# 10     1982  102    102
# 11     1983  190    194
# 12     1984  185    192
# 13     1985   50     56
# 14     1986   48     53
# 15     1987   34     38
# 16     1988   24     28
# 17     1989   25     26
# 18     1990   20     21
# 19     1991   36     40
# 20     1992   78     81
# 21     1993   84     85
# 22     1994   40    111
# 23     1995  106    123
# 24     1996   77    136
# 25     1997  105    160
# 26     1998   75    162
# 27     1999  141    153
# 28     2000   86    146
# 29     2001    0    171
# 30     2002    0    183
# 31     2003    1    184
# 32     2004    1    181
# 33     2005    2    177
# 34     2006    9    175
# 35     2007   56    160
# 36     2008  216    218
# 37     2009  190    194
# 38     2010  179    193
# 39     2011  177    185
# 40     2012  173    185
# 41     2013  181    190
# 42     2014  185    191
# 43     2015  181    192
# 44     2016  188    195
# 45     2017  183    186
# 46     2018  176    192
# 47     2019  171    186
# 48     2020  123    134
# 49     2021  196    202
# 50     2022   61     62
